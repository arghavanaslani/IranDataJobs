# %%
from bs4 import BeautifulSoup
import pandas as pd
import os
import re
import requests

# %%
# csv_file_path = '/kaggle/input/job-ad-html/links.csv'
# df = pd.read_csv(csv_file_path)
    
# Define a function to process HTML content
def process_html_content(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    
    job_title_element = soup.find('span', class_='w-100 text-truncate font-weight-bold mb-1')
    company_name_element = soup.find('span', class_='w-100 text-truncate')
    
    location_element = soup.find('div', class_='text-black mb-1', string=re.compile('Location|محل کار'))
    location_value_element = location_element.find_next('div', class_='col-auto px-0 ng-star-inserted')

    city_name = location_value_element.find('span').get_text(strip=True) if location_value_element.find('span') else None
    neighborhood = location_value_element.get_text(strip=True).replace(city_name, '').strip()

    
    if neighborhood == city_name:
        neighborhood = None

    location = {
        'City': city_name,
        'Neighborhood': neighborhood
    }
    
    working_days_element = soup.find('div', class_='text-black mb-1', string=re.compile('Working days and hours|روز و ساعت کاری'))
    working_days = working_days_element.find_next('div').get_text(strip=True) if working_days_element else None
    
    job_type_element = soup.find('div', class_='text-black mb-1', string=re.compile('Contract type|نوع همکاری'))
    job_type = job_type_element.find_next('div').get_text(strip=True) if job_type_element else None
    

    key_indicator_section = soup.find('h1', string=re.compile('شاخص های کلیدی از نظر کارفرما|key Requirements'))
    key_indicators = []

    if key_indicator_section:
        parent_divs = key_indicator_section.find_all_next('div', class_=re.compile('col-12 mb-3 (pl-0|pr-0) ng-star-inserted'))

        for parent_div in parent_divs:
            key_requirement = parent_div.find('span', class_='col ml-2 px-0 word-break')
            if key_requirement:
                key_indicators.append(key_requirement.get_text(strip=True))
            else:
                key_requirement = parent_div.find('div', class_='row col-11 px-0')
                if key_requirement:
                    sub_items = key_requirement.find_all(['span', 'div'], recursive=False)
                    for item in sub_items:
                        key_indicators.append(item.get_text(strip=True))

    

    job_description_section = soup.find('h1', string=re.compile('Job Description|شرح شغل و وظایف'))
    job_description_list = []
    if job_description_section:
        job_description_items = job_description_section.find_next('div', class_='col-12 row text-black px-0 mb-3')
        if job_description_items:
            job_description_element = job_description_items.find('div', class_='col px-0 mr-2')
            if job_description_element:
                paragraphs = job_description_element.find_all('p')
                for p in paragraphs:
                    job_description_list.extend(p.stripped_strings)
        else:
            job_description_element = job_description_section.find_next('p')
            if job_description_element:
                job_description_list.extend(job_description_element.stripped_strings)
    else:
        job_description_list.append(None)  # Append None for rows without Job Description section


    
    condition_section = soup.find('h1', string=re.compile('شرایط احراز شغل|Job Requirements'))
    condition_list = []
    if condition_section:
        condition_items = condition_section.find_next('div', class_='col-12 row px-0')
        for item in condition_items.find_all('div', class_='col-12 row align-items-center justify-content-between px-0 mb-3 ng-star-inserted'):
            title = item.find('div', class_='requirement-title').get_text(strip=True)
            value = item.find('div', class_='requirement-value').get_text(strip=True)
            condition_list.append((title, value))

    
    data = {'Job Title': job_title_element.get_text(strip=True) if job_title_element else None,
            'Company Name': company_name_element.get_text(strip=True) if company_name_element else None,
            'Location': location,
            'Working Days': working_days,
            'Job Type': job_type,
            'Key Indicators': key_indicators,
            'Job Description': job_description_list,
            'Job Conditions': condition_list}
    
    return data

# Directory containing your text files with HTML content
html_files_dir = '/kaggle/input/job-ad-html'

# List to store processed data
data_list = []

# Process each text file in the directory
for filename in os.listdir(html_files_dir):
    if filename.endswith('.txt'):
        file_path = os.path.join(html_files_dir, filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            html_content = file.read()
        processed_data = process_html_content(html_content)
        data_list.append(processed_data)
        
# # Process each URL in the DataFrame
# for url in df['URL']:
#     response = requests.get(url)
#     html_content = response.content
#     processed_data = process_html_content(html_content)
#     data_list.append(processed_data)

# Create a DataFrame from the processed data
df = pd.DataFrame(data_list)

# Print the DataFrame
df.head(50)
# Out:
#                                           Job Title  \
# 0                                      تحلیلگر داده
# 1                    کارشناس تحلیل داده و هوش تجاری
# 2                                      کارشناس آمار
# 3                            برنامه نویس هوش مصنوعی
# 4                            کارشناس هوش تجاری (BI)
# 5                                      Data Analyst
# 6                       Data Designer and Developer
# 7                                  کارشناس Power BI
# 8                              Senior Data Engineer
# 9                              کارشناس تحلیلگر داده
# 10         کارشناس ارشد هوش مصنوعی (توسعه الگوریتم)
# 11                               کارشناس تحلیل داده
# 12                           برنامه نویس هوش مصنوعی
# 13               کارشناس تحلیل داده (Data Analysis)
# 14                           برنامه نویس هوش مصنوعی
# 15                           برنامه نویس هوش مصنوعی
# 16                              کارشناس پایگاه داده
# 17            کارشناس بخش تحقیق و توسعه (R&D)- خانم
# 18                       مهندس داده (Data Engineer)
# 19                             کارشناس پردازش تصویر
# 20                      متخصص پردازش سیگنال و گفتار
# 21                  کارشناس هوش تجاری (عملیات - BI)
# 22                 برنامه نویس هوش مصنوعی و روباتیک
# 23                               کارشناس تحلیل داده
# 24                       محقق داده (Data Scientist)
# 25                              Data Scientist Lead
# 26                           Database Administrator
# 27                                       کارشناس BI
# 28                     منتور علم داده (Data Mentor)
# 29                                     Data Analyst
# 30                           تحلیلگر هوش تجاری (BI)
# 31                کارشناس تحلیل داده (Data Analyst)
# 32                                     Data Analyst
# 33                               کارشناس هوش مصنوعی
# 34                               سرپرست آنالیز دیتا
# 35                کارشناس بینایی ماشین و هوش مصنوعی
# 36      کارشناس ارشد تحلیل داده (صنعت بانکی و مالی)
# 37  machine learning engineer (مهندس یادگیری ماشین)
# 38                           برنامه نویس هوش مصنوعی
# 39                           کارشناس پایگاه داده BI
# 40         کارشناس داده کاوی و آنالیز (Data Mining)
# 41             توسعه دهنده هوش تجاری (BI Developer)
# 42                            Business Data Analyst
# 43                                 متخصص هوش مصنوعی
# 44     Data Scientist - Marketing Models Specialist
# 45                                     Data Analyst
# 46                                کارشناس هوش تجاری
# 47              کارشناس پایگاه داده اوراکل (Oracle)
# 48                                     Data Analyst
# 49                 کارشناس پایگاه داده (SQL Server)
#
#                                      Company Name  \
# 0                                     ارکید فارمد
# 1                          صنایع بسته بندی به بند
# 2                                     ارکید فارمد
# 3                                          فراهوش
# 4                                   گروه صنعتی زر
# 5                Esmiran International Trading Co
# 6                                      Hafhashtad
# 7                                انتخاب الکترونیک
# 8                                        Sheypoor
# 9                                       هیژا دارو
# 10                                         متیران
# 11                       سامان پویش تامین - اسپات
# 12                                         فراهوش
# 13              باغ دارو سبز سلامت گستر پنجاه چهل
# 14                                         فراهوش
# 15                                         فراهوش
# 16                               پرداخت نوین آرین
# 17                                       هازل شاپ
# 18                                          مهسان
# 19                               بهین علم فراجهان
# 20                           شرکت داده پرداز آفاق
# 21        توسعه سامانه های نرم افزاری نگین - توسن
# 22                                     گروه پیروی
# 23                             آداک فناوران آینده
# 24                                  رستافن ارتباط
# 25                                        Digipay
# 26               گروه صنعتی وطن زرین مروارید آسیا
# 27                      پرداخت الکترونیک پاسارگاد
# 28                                           گلرن
# 29                                     خدمت از ما
# 30            هایپرمارکتهای ماف پارس - هایپراستار
# 31                     بیمه پاسارگاد (دفتر مرکزی)
# 32                                      snappfood
# 33                                        ویرا110
# 34                              پرگاس طب (لافارر)
# 35                              رادمان سیستم ویژن
# 36  شرکت داده و اعتبار سنجی تجارت ایرانیان (داتا)
# 37                           شرکت هوش مصنوعی گاتا
# 38                       توسعه دانش و فناوری کارن
# 39                                        بانک دی
# 40              باغ دارو سبز سلامت گستر پنجاه چهل
# 41                                       هوش آیند
# 42                                          Okala
# 43                                        فلونیتا
# 44                                 OK Chainstores
# 45                       Behin Bazaar Negar Exxon
# 46                             نویان نگین پارسیان
# 47                فناوری اطلاعات و ارتباطات مهیمن
# 48                                    گروه ارنیکا
# 49                                         چارسوق
#
#                                              Location  \
# 0          {'City': 'تهران', 'Neighborhood': '، ونک'}
# 1   {'City': 'تهران', 'Neighborhood': '، عباس آباد...
# 2          {'City': 'تهران', 'Neighborhood': '، ونک'}
# 3      {'City': 'شیراز', 'Neighborhood': '، آب جوار'}
# 4                 {'City': 'کرج', 'Neighborhood': ''}
# 5   {'City': 'Tehran', 'Neighborhood': ', Andarzgoo'}
# 6       {'City': 'Tehran', 'Neighborhood': ', Vanak'}
# 7              {'City': 'اصفهان', 'Neighborhood': ''}
# 8       {'City': 'Tehran', 'Neighborhood': ', Vanak'}
# 9     {'City': 'تهران', 'Neighborhood': '، میرداماد'}
# 10     {'City': 'تهران', 'Neighborhood': '، سهروردی'}
# 11     {'City': 'تهران', 'Neighborhood': '، اکباتان'}
# 12               {'City': 'اراک', 'Neighborhood': ''}
# 13        {'City': 'تهران', 'Neighborhood': '، پونک'}
# 14              {'City': 'کرمان', 'Neighborhood': ''}
# 15               {'City': 'ساری', 'Neighborhood': ''}
# 16  {'City': 'تهران', 'Neighborhood': '، سعادت آباد'}
# 17  {'City': 'تهران', 'Neighborhood': '، کریمخان ز...
# 18  {'City': 'تهران', 'Neighborhood': '، عباس آباد...
# 19        {'City': 'تهران', 'Neighborhood': '، طرشت'}
# 20       {'City': 'تهران', 'Neighborhood': '، رسالت'}
# 21       {'City': 'تهران', 'Neighborhood': '، گاندی'}
# 22    {'City': 'تهران', 'Neighborhood': '، پاسداران'}
# 23  {'City': 'تهران', 'Neighborhood': '، میدان ولی...
# 24      {'City': 'تهران', 'Neighborhood': '، شریعتی'}
# 25     {'City': 'Tehran', 'Neighborhood': ', Jordan'}
# 26  {'City': 'تهران', 'Neighborhood': '، عباس آباد...
# 27  {'City': 'تهران', 'Neighborhood': '، سعادت آباد'}
# 28               {'City': 'ساری', 'Neighborhood': ''}
# 29              {'City': 'شیراز', 'Neighborhood': ''}
# 30      {'City': 'تهران', 'Neighborhood': '، شریعتی'}
# 31       {'City': 'تهران', 'Neighborhood': '، فاطمی'}
# 32   {'City': 'Tehran', 'Neighborhood': ', Mirdamad'}
# 33               {'City': 'مشهد', 'Neighborhood': ''}
# 34        {'City': 'تهران', 'Neighborhood': '، جردن'}
# 35    {'City': 'تهران', 'Neighborhood': '، ایرانشهر'}
# 36         {'City': 'تهران', 'Neighborhood': '، ونک'}
# 37     {'City': 'تهران', 'Neighborhood': '، هفت تیر'}
# 38    {'City': 'تهران', 'Neighborhood': '، پاسداران'}
# 39   {'City': 'تهران', 'Neighborhood': '، آذربایجان'}
# 40        {'City': 'تهران', 'Neighborhood': '، پونک'}
# 41  {'City': 'تهران', 'Neighborhood': '، بلوار کشا...
# 42   {'City': 'Tehran', 'Neighborhood': ', Arjantin'}
# 43  {'City': 'تهران', 'Neighborhood': '، شهرک دانش...
# 44  {'City': 'Tehran', 'Neighborhood': ', Yosef Ab...
# 45   {'City': 'Tehran', 'Neighborhood': ', Mirdamad'}
# 46  {'City': 'تهران', 'Neighborhood': '، آیت الله ...
# 47  {'City': 'تهران', 'Neighborhood': '، عباس آباد...
# 48        {'City': 'تهران', 'Neighborhood': '، قلهک'}
# 49    {'City': 'تهران', 'Neighborhood': '، آرژانتین'}
#
#                                          Working Days              Job Type  \
# 0                                    شنبه تا چهارشنبه              تمام وقت
# 1                 شنبه تا چهارشنبه ساعت 8:00 تا 17:00              تمام وقت
# 2                                    شنبه تا چهارشنبه              تمام وقت
# 3                        شنبه تا پنجشنبه ساعت 8 تا 15  تمام وقت یا پاره وقت
# 4                           شنبه تا چهارشنبه 8 الی 17              تمام وقت
# 5   Saturday to Wednesday From 8 to 16:30- Thursda...             Full Time
# 6                                    شنبه تا چهارشنبه             Full Time
# 7                           شنبه تا چهارشنبه 8 الی 17              تمام وقت
# 8                     Saturday to Wednesday 9 till 18             Full Time
# 9   شنبه تا چهارشنبه ساعت 8:00 الی 16:00   و پنجشن...              تمام وقت
# 10             شنبه تا چهارشنبه از ساعت 7:30 تا 16:30              تمام وقت
# 11  شنبه تا چهارشنبه 7:30 - 16:00 ، پنجشنبه ها 7:3...              تمام وقت
# 12                       شنبه تا پنجشنبه ساعت 8 تا 15  تمام وقت یا پاره وقت
# 13                                        8 الی 16:30              تمام وقت
# 14                       شنبه تا پنجشنبه ساعت 8 تا 15  تمام وقت یا پاره وقت
# 15                       شنبه تا پنجشنبه ساعت 8 تا 15  تمام وقت یا پاره وقت
# 16                              8-17 شنبه تا چهارشنبه              تمام وقت
# 17  شنبه تا چهارشنبه از ساعت 9 الی 17 و پنجشنبه ها...              تمام وقت
# 18                   شنبه تا چهارشنبه - 8:00 تا 16:45              تمام وقت
# 19                                    44 ساعت در هفته              تمام وقت
# 20                    شنبه تا چهار شنبه 8:00 تا 16:50              تمام وقت
# 21                        شنبه تا چهارشنبه 8 تا 16:30              تمام وقت
# 22                   شنبه الی چهارشنبه 9:30 الی 18:00              تمام وقت
# 23  از شنبه تا چهارشنبه 9:30 تا 18:30 پنج شنبه تا ...              تمام وقت
# 24                                  شنبه الی چهارشنبه              تمام وقت
# 25             Saturdays- Wednesdays (Flexible Hours)             Full Time
# 26                    شنبه تا چهارشنبه 07:30 تا 16:30              تمام وقت
# 27     روزهای شنبه تا چهارشنبه از ساعت 08:00 تا 17:00              تمام وقت
# 28                                        قابل مذاکره   قراردادی / پروژه ای
# 29                            شنبه تا پنچشنبه 8 تا 14              تمام وقت
# 30                                 یکشنبه الی پنجشنبه              تمام وقت
# 31  شنبه تا چهارشنبه ( 7:00الی 14:30) و پنجشنبه ها...              تمام وقت
# 32                     Saturday to Wednesday 10 to 19             Full Time
# 33                      شنبه تا پنج شنبه ساعت 12 تا 7   قراردادی / پروژه ای
# 34  شنبه  از ساعت 8:30 تا 17:30 و پنجشنبه از ساعت ...              تمام وقت
# 35           متناسب با پروژه زمان کار انعطاف پذیر است   قراردادی / پروژه ای
# 36                      شنبه تا چهارشنبه ساعت 8 تا 17              تمام وقت
# 37  یکشنبه تا پنجشنبه 8:00 الی 17:00 جمعه و شنبه ت...              تمام وقت
# 38                          شنبه تا چهارشنبه 8 الی 17              تمام وقت
# 39                                      6 روز در هفته              تمام وقت
# 40                                           8 الی 18              تمام وقت
# 41                      شنبه تا چهارشنبه ساعت 8 تا 17              تمام وقت
# 42            Saturday to Wednesday from 9 am to 6 pm             Full Time
# 43                 ایام هفته به جز روز های تعطیل رسمی   قراردادی / پروژه ای
# 44  Saturdays - Wednesdays (8-17) - Thursdays(8-12...             Full Time
# 45                 Sat-Wed 8:30-16:50, Thu 8:30-13:50             Full Time
# 46     شنبه تا چهارشنبه 8 الی 16:30 پنج شنبه 8 الی 12              تمام وقت
# 47                شنبه تا چهارشنبه 8-16 پنج شنبه 8-12              تمام وقت
# 48                         شنبه تا پنج شنبه  9 الی 18              تمام وقت
# 49  شنبه تا چهارشنبه از 8:00 تا 16:45و پنج شنبه ها...              تمام وقت
#
#                                        Key Indicators  \
# 0                 [Python - پیشرفته, T-Sql - پیشرفته]
# 1   [Sql Server - پیشرفته, PowerBI - پیشرفته, SSIS...
# 2                          [Stata - متوسط, R - متوسط]
# 3                                    [Python - متوسط]
# 4                                   [PowerBI - متوسط]
# 5            [4 years experience in similar position]
# 6            [2 years experience in similar position]
# 7                                                  []
# 8            [3 years experience in similar position]
# 9   [Microsoft Word - متوسط, Microsoft Excel - متوسط]
# 10                                                 []
# 11  [Sql Server - پیشرفته, T-Sql - پیشرفته, Micros...
# 12                 [Python - متوسط, Rest API - متوسط]
# 13  [Microsoft Word - متوسط, Microsoft Excel - پیش...
# 14                                   [Python - متوسط]
# 15                                   [Python - متوسط]
# 16  [Sql Server - پیشرفته, Oracle Database - متوسط...
# 17  [Microsoft Word - متوسط, Microsoft Excel - متو...
# 18  [Java - پیشرفته, Python - متوسط, Linux - متوسط...
# 19                                 [OpenCV - پیشرفته]
# 20                                 [Python - پیشرفته]
# 21  [Sql Server - متوسط, PowerBI - پیشرفته, SSIS -...
# 22  [Microsoft Word - متوسط, Microsoft Excel - متو...
# 23  [Google Analytics - متوسط, Google Search Conso...
# 24                                                 []
# 25  [5 years experience in similar position, Manag...
# 26                                  [T-Sql - پیشرفته]
# 27  [Sql Server - متوسط, PowerBI - پیشرفته, SSIS -...
# 28  [Sql Server - متوسط, MySql - مقدماتی, PostgreS...
# 29  [Microsoft Excel - متوسط, Python - متوسط, Goog...
# 30  [PostgreSql - پیشرفته, Python - پیشرفته, Power...
# 31  [Microsoft Word - پیشرفته, Microsoft Excel - پ...
# 32           [2 years experience in similar position]
# 33  [Python - متوسط, GIT - مقدماتی, Linux - مقدمات...
# 34  [Microsoft Excel - پیشرفته, SPSS - متوسط, Pyth...
# 35                 [Python - متوسط, OpenCV - پیشرفته]
# 36                    [Python - متوسط, T-Sql - متوسط]
# 37  [MySql - متوسط, Python - متوسط, Hadoop - مقدما...
# 38  [MySql - متوسط, Python - متوسط, GIT - پیشرفته,...
# 39  [Microsoft Excel - پیشرفته, Sql Server - متوسط...
# 40                        [Microsoft Excel - پیشرفته]
# 41  [Sql Server - متوسط, T-Sql - متوسط, Qlikview -...
# 42           [3 years experience in similar position]
# 43  [C# - متوسط, Python - متوسط, Html & CSS - پیشر...
# 44  [2 years experience in similar position, Bache...
# 45           [3 years experience in similar position]
# 46  [Knime - مقدماتی, PowerBI - متوسط, SSIS - متوس...
# 47                                                 []
# 48  [Sql Server - متوسط, Google Analytics - پیشرفت...
# 49  [Sql Server - پیشرفته, T-Sql - پیشرفته, SSRS -...
#
#                                       Job Description  \
# 0   [خلق ارزش و آگاهی دادن به واحد های مختلف با کم...
# 1   [وظایف اصلی, -طراحی انبار داده (Data Warehouse...
# 2   [·, کارشناسی ارشد آمار زیستی، ریاضی، بیمه و اق...
# 3   [جای شما در تیم استارتاپی فراهوش خالیه...!, شر...
# 4   [تسلط به  نرم افزار  هوش تجاری (POWER BI), آشن...
# 5   [We are seeking a talented Data Analyst to joi...
# 6   [Our Data team at Haf-hashtad is looking for a...
# 7                                                  []
# 8   [Sheypoor is seeking an accomplished senior da...
# 9   [تحصیلات:, مدرک کارشناسی رشته صنایع، آمار و سا...
# 10  [توسعه الگوریتم های هوش مصنوعی, مطالعه و شناسا...
# 11                                                 []
# 12  [جای شما در تیم استارتاپی فراهوش خالیه...!, شر...
# 13  [شرایط احراز:, مسلط به کار با اکسل بصورت حرفه ...
# 14  [جای شما در تیم استارتاپی فراهوش خالیه...!, شر...
# 15  [جای شما در تیم استارتاپی فراهوش خالیه...!, شر...
# 16                    [شرح شغل و مهارتهای مورد نیاز:]
# 17   [شرح شغل و وظایف, شرایط مورد نیاز, حقوق و مزایا]
# 18  [مسئولیت های موقعیت شغلی مهندس داده (Data Engi...
# 19  [مسلط به الگوریتم ها و روش های مبتنی بر GAN در...
# 20  [استخدام متخصص پردازش سیگنال و گفتار با تسلط خ...
# 21  [وظایف:, شرایط احراز:, موارد زیر مزیت محسوب می...
# 22  [در این جایگاه فرد نیاز به تجربه در حوضه compu...
# 23  [استخراج و بررسی دیتای مختلف سازمان(آنلاین،سای...
# 24               [شرح شغل و وظایف:, شرایط و تخصص ها:]
# 25  [Mentor and supervise data science aspects of ...
# 26  [مهارت های مورد نیاز :, ·         نصب ، پیکربن...
# 27              [مهارت های تخصصی و رفتاری مورد نیاز:]
# 28  [گُل اِرن با توجه به رسالتی که در زمینه توسعه ...
# 29  [شرح موقعیت شغلی, ما در تیم خدمت از ما، در جست...
# 30                                                 []
# 31  [شرح شغل:, - طراحی داشبردهای مدیریتی, - داده ک...
# 32  [In the story of Snappfood, we want to create ...
# 33  [شرح موقعیت شغلی, شرکت ویرا110 فعال در حوزه پر...
# 34  [1. مسلط به مباحث آماری, 2. توانایی تحلیل داده...
# 35  [حداقل لیسانس یا فوق لیسانس رشته های برق، کامپ...
# 36  [شرایط احراز:, تسلط کامل به الگوریتم های داده ...
# 37  [ما در حال حاضر در گاتا به دنبال یک machine le...
# 38  [شرح شغل, توانمندی, مزایا, • امکان شناوری در س...
# 39  [تسلط بر دیتابیس های اوراکل، SQL Server ، PL S...
# 40  [آشنایی با الگوریتم های داده کاوی، روش های تحل...
# 41  [خلاصه شغل:, در هوش آیند به دنبال یک هم تیمی ب...
# 42  [In the data department, we aim to enable the ...
# 43  [هرگونه پیشنهاد کاربری هوش مصنوعی در ساختار و ...
# 44               [Job Description:, Required Skills:]
# 45  [Are you passionate about uncovering insights ...
# 46  [شرح شغل:, آشنا به نرم افزار ERP, آشنایی با مف...
# 47                     [شرح شغل:, نیازمندی های شغلی:]
# 48  [شرح وظایف:, شرایط احراز تخصصی :, شرایط احراز ...
# 49  [تسلط به زبان TSQL (پرس و جوهای بازگشتی، توابع...
#
#                                        Job Conditions
# 0   [(سن, 25 - 35 سال), (جنسیت, تفاوتی ندارد), (تح...
# 1   [(جنسیت, تفاوتی ندارد), (خدمت سربازی, اتمام خد...
# 2   [(سن, 25 - 35 سال), (جنسیت, تفاوتی ندارد), (تح...
# 3   [(سن, 24 - 40 سال), (جنسیت, ترجیحاً خانم), (نر...
# 4   [(سن, 25 - 36 سال), (جنسیت, تفاوتی ندارد), (خد...
# 5   [(Age, 20 - 35 Years Old), (Gender, Men / Wome...
# 6   [(Age, 25 - 45 Years Old), (Gender, Men / Wome...
# 7   [(سن, 23 - 38 سال), (جنسیت, تفاوتی ندارد), (خد...
# 8   [(Age, 23 - 33 Years Old), (Gender, Men / Wome...
# 9   [(سن, 22 - 30 سال), (جنسیت, تفاوتی ندارد), (تح...
# 10  [(سن, 20 - 40 سال), (جنسیت, تفاوتی ندارد), (تح...
# 11  [(سن, 25 - 35 سال), (جنسیت, تفاوتی ندارد), (خد...
# 12  [(سن, 24 - 40 سال), (جنسیت, ترجیحاً خانم), (نر...
# 13  [(سن, 22 - 40 سال), (جنسیت, تفاوتی ندارد), (تح...
# 14  [(سن, 24 - 40 سال), (جنسیت, ترجیحاً خانم), (نر...
# 15  [(سن, 24 - 40 سال), (جنسیت, ترجیحاً خانم), (نر...
# 16  [(سن, 24 - 50 سال), (جنسیت, تفاوتی ندارد), (خد...
# 17  [(سن, 24 - 40 سال), (جنسیت, فقط خانم), (تحصیلا...
# 18  [(سن, 20 - 35 سال), (جنسیت, تفاوتی ندارد), (نر...
# 19  [(جنسیت, تفاوتی ندارد), (زبان, انگلیسی|بالاتر ...
# 20  [(سن, 20 - 40 سال), (جنسیت, ترجیحاً آقا), (تحص...
# 21  [(سن, 25 - 35 سال), (جنسیت, تفاوتی ندارد), (خد...
# 22  [(سن, 22 - 40 سال), (جنسیت, تفاوتی ندارد), (تح...
# 23  [(سن, 23 - 33 سال), (جنسیت, تفاوتی ندارد), (نر...
# 24  [(جنسیت, تفاوتی ندارد), (تحصیلات, کارشناسی|کام...
# 25  [(Gender, Men / Women), (Military service, Mil...
# 26  [(سن, 23 - 43 سال), (جنسیت, تفاوتی ندارد), (خد...
# 27  [(سن, 23 - 36 سال), (جنسیت, تفاوتی ندارد), (تح...
# 28  [(سن, 24 - 38 سال), (جنسیت, تفاوتی ندارد), (تح...
# 29  [(جنسیت, تفاوتی ندارد), (نرم افزارها, PowerBI|...
# 30  [(جنسیت, تفاوتی ندارد), (خدمت سربازی, اتمام خد...
# 31  [(سن, 22 - 32 سال), (جنسیت, تفاوتی ندارد), (خد...
# 32  [(Gender, Men / Women), (Software, Python|Inte...
# 33  [(جنسیت, تفاوتی ندارد), (نرم افزارها, Python|م...
# 34  [(سن, 25 - 40 سال), (جنسیت, تفاوتی ندارد), (خد...
# 35  [(جنسیت, تفاوتی ندارد), (تحصیلات, کارشناسی|کام...
# 36  [(سن, از 28 سال), (جنسیت, تفاوتی ندارد), (نرم ...
# 37  [(جنسیت, تفاوتی ندارد), (تحصیلات, کارشناسی|کام...
# 38  [(جنسیت, تفاوتی ندارد), (نرم افزارها, Jira|متو...
# 39  [(سن, 22 - 40 سال), (جنسیت, تفاوتی ندارد), (خد...
# 40  [(سن, 22 - 40 سال), (جنسیت, تفاوتی ندارد), (تح...
# 41  [(سن, 23 - 33 سال), (جنسیت, تفاوتی ندارد), (نر...
# 42  [(Gender, Men / Women), (Software, T-Sql|Inter...
# 43  [(جنسیت, تفاوتی ندارد), (تحصیلات, کارشناسی ارش...
# 44  [(Age, 24 - 38 Years Old), (Gender, Men / Wome...
# 45                            [(Gender, Men / Women)]
# 46  [(سن, 25 - 35 سال), (جنسیت, تفاوتی ندارد), (خد...
# 47         [(سن, 25 - 45 سال), (جنسیت, تفاوتی ندارد)]
# 48  [(جنسیت, تفاوتی ندارد), (نرم افزارها, PowerBI|...
# 49  [(سن, 22 - 32 سال), (جنسیت, تفاوتی ندارد), (نر...
